# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

def get_spotify_control():
    load_dotenv()
    birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Portraits (+ Remixes)
# Portraits
# Young Heart
# Beautiful Lies (Deluxe)
# Beautiful Lies
# Fire Within (Deluxe)
# Fire Within
# Live in London
# Birdy (Deluxe Version)
# Birdy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Rock and Roll - Remaster
# audio    : https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Good Times Bad Times - 1993 Remaster
# audio    : https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32
#
# track    : Ramble On - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Kashmir - Remaster
# audio    : https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e
#
# track    : Going to California - Remaster
# audio    : https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Over the Hills and Far Away - Remaster
# audio    : https://p.scdn.co/mp3-preview/a828935e429be801aa374eeeb8b2cb0d91755d57?cid=0b88d92ddca94bbe8f79556f651736a3
# cover art: https://i.scdn.co/image/ab67616d0000b2731aa47e71c4edfeaddb65cd54

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

name = 'Mad World'

results = spotify.search(q='song:' + name, type='artist')
print(results)
# items = results['artists']['items']
# if len(items) > 0:
#     artist = items[0]
#     print(artist['name'], artist['images'][0]['url'])
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=song%3AMad+World&type=artist&offset=0&limit=10', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NjQwMI9JSTwnIEKWD0VuI'}, 'followers': {'href': None, 'total': 23}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/2NjQwMI9JSTwnIEKWD0VuI', 'id': '2NjQwMI9JSTwnIEKWD0VuI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27326e8ab21837dabd7f299903c', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0226e8ab21837dabd7f299903c', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485126e8ab21837dabd7f299903c', 'width': 64}], 'name': 'The Mad Wookiees', 'popularity': 22, 'type': 'artist', 'uri': 'spotify:artist:2NjQwMI9JSTwnIEKWD0VuI'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/62aahVSTz0mx0dbZr41NAq'}, 'followers': {'href': None, 'total': 1130}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/62aahVSTz0mx0dbZr41NAq', 'id': '62aahVSTz0mx0dbZr41NAq', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb7a04516a7eb3fe7f9355106e', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051747a04516a7eb3fe7f9355106e', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1787a04516a7eb3fe7f9355106e', 'width': 160}], 'name': 'MADWOMAN', 'popularity': 4, 'type': 'artist', 'uri': 'spotify:artist:62aahVSTz0mx0dbZr41NAq'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/19wBYgEXlCxE8QGpT5CVwn'}, 'followers': {'href': None, 'total': 5046}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/19wBYgEXlCxE8QGpT5CVwn', 'id': '19wBYgEXlCxE8QGpT5CVwn', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2737883b31c0123a2bea7dd5085', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ad7839b23c4ac1ed23938616', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ad7839b23c4ac1ed23938616', 'width': 64}], 'name': 'Mad World', 'popularity': 2, 'type': 'artist', 'uri': 'spotify:artist:19wBYgEXlCxE8QGpT5CVwn'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0iicBjMtiqWncOUddzmfuP'}, 'followers': {'href': None, 'total': 48}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0iicBjMtiqWncOUddzmfuP', 'id': '0iicBjMtiqWncOUddzmfuP', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb0d0c6e28ee237ac014a20af3', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051740d0c6e28ee237ac014a20af3', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1780d0c6e28ee237ac014a20af3', 'width': 160}], 'name': 'MadWolf Music', 'popularity': 2, 'type': 'artist', 'uri': 'spotify:artist:0iicBjMtiqWncOUddzmfuP'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1BS1spGzg8FthkXYhxvMKD'}, 'followers': {'href': None, 'total': 3}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1BS1spGzg8FthkXYhxvMKD', 'id': '1BS1spGzg8FthkXYhxvMKD', 'images': [], 'name': 'Madworld', 'popularity': 1, 'type': 'artist', 'uri': 'spotify:artist:1BS1spGzg8FthkXYhxvMKD'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1rNvN9QFulbqAeqydUqZrI'}, 'followers': {'href': None, 'total': 187}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1rNvN9QFulbqAeqydUqZrI', 'id': '1rNvN9QFulbqAeqydUqZrI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb03e23c731a1bc8943080f31b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517403e23c731a1bc8943080f31b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17803e23c731a1bc8943080f31b', 'width': 160}], 'name': 'Madwill', 'popularity': 8, 'type': 'artist', 'uri': 'spotify:artist:1rNvN9QFulbqAeqydUqZrI'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7e9W8KQwKCXBxtjipOM5CA'}, 'followers': ...

# %%
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3A--f%3Dc%3A%5CUsers%5Cwelcome%5CAppData%5CRoaming%5Cjupyter%5Cruntime%5Ckernel-v2-8120ZAfflF56UVtj.json&type=artist&offset=0&limit=10',
#   'items': [],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %% [markdown]
# Auth using OAAuth

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv
load_dotenv()
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\oauth2.py:559, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     551 response = self._session.post(
#     552     self.OAUTH_TOKEN_URL,
#     553     data=payload,
#    (...)
#     557     timeout=self.requests_timeout,
#     558 )
# --> 559 response.raise_for_status()
#     560 token_info = response.json()
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[13], line 9
#       5 scope = "user-library-read"
#       7 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
# ----> 9 results = sp.current_user_saved_tracks()
#      10 for idx, item in enumerate(results['items']):
#      11     track = item['track']
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\client.py:1286, in Spotify.current_user_saved_tracks(self, limit, offset, market)
#    1276 def current_user_saved_tracks(self, limit=20, offset=0, market=None):
#    1277     """ Gets a list of the tracks saved in the current authorized user's
#    1278         "Your Music" library
#    1279
#    (...)
#    1284
#    1285     """
# -> 1286     return self._get("me/tracks", limit=limit, offset=offset, market=market)
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\oauth2.py:565, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     563     return token_info if as_dict else token_info["access_token"]
#     564 except requests.exceptions.HTTPError as http_error:
# --> 565     self._handle_oauth_error(http_error)
#
# File c:\Repository\100 Days of Code\.venv\Lib\site-packages\spotipy\oauth2.py:146, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     143     error = response.text or None
#     144     error_description = None
# --> 146 raise SpotifyOauthError(
#     147     'error: {0}, error_description: {1}'.format(
#     148         error, error_description
#     149     ),
#     150     error=error,
#     151     error_description=error_description
#     152 )
#
# SpotifyOauthError: error: invalid_request, error_description: code must be supplied

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 SpotifyOAuth.get_authorize_url()
#
# TypeError: SpotifyOAuth.get_authorize_url() missing 1 required positional argument: 'self'

# %%
import spotify as sp
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Perfect&type=track&offset=0&limit=1', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'}, 'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V', 'id': '6eUKZXaKkcviH0Ku9w2n3V', 'name': 'Ed Sheeran', 'type': 'artist', 'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'}, 'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu', 'id': '3T4tUhGYeRNVUGevb0wThu', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96', 'width': 64}], 'name': '÷ (Deluxe)', 'release_date': '2017-03-03', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'}, 'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V', 'id': '6eUKZXaKkcviH0Ku9w2n3V', 'name': 'Ed Sheeran', 'type': 'artist', 'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 263400, 'explicit': False, 'external_ids': {'isrc': 'GBAHS1700024'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0tgVpDi06FyKpA1z0VMD4v'}, 'href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v', 'id': '0tgVpDi06FyKpA1z0VMD4v', 'is_local': False, 'name': 'Perfect', 'popula ...

# %%
song=sp.search_a_song('Hakuna Matata')

# %%
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Hakuna+Matata&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7nMexBA71PdwPnfqS5Yji5'},
#      'href': 'https://api.spotify.com/v1/albums/7nMexBA71PdwPnfqS5Yji5',
#      'id': '7nMexBA71PdwPnfqS5Yji5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f062b7159e8f230120512bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f062b7159e8f230120512bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f062b7159e8f230120512bf',
#        'width': 64}],
#      'name': 'Coco (Original Motion Picture Soundtrack)',
#      'release_date': '2017-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 53,
#      'type': 'album',
#      'uri': 'spotify:album:7nMexBA71PdwPnfqS5Yji5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2q10Wskc3lPYmEuV7rzMCv'},
#       'href': 'https://api.spotify.com/v1/artists/2q10Wskc3lPYmEuV7rzMCv',
#       'id': '2q10Wskc3lPYmEuV7rzMCv',
#       'name': 'Anthony Gonzalez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2q10Wskc3lPYmEuV7rzMCv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/09oR0uKhqwScsKa2eUK97p'},
#       'href': 'https://api.spotify.com/v1/artists/09oR0uKhqwScsKa2eUK97p',
#       'id': '09oR0uKhqwScsKa2eUK97p',
#       'name': 'Gael Garcia Bernal',
#       'type': 'artist',
#       'uri': 'spotify:artist:09oR0uKhqwScsKa2eUK97p'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 112205,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11783639'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0OFknyqxmSQ42SoKxWVTok'},
#     'href': 'https://api.spotify.com/v1/tracks/0OFknyqxmSQ42SoKxWVTok',
#     'id': '0OFknyqxmSQ42SoKxWVTok',
#     'is_local': False,
#     'name': 'Un Poco Loco',
#     'popularity': 71,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0OFknyqxmSQ42SoKxWVTok'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Hakuna+Matata&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 802}}
